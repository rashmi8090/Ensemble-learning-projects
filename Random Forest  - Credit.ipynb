# %%
import pandas as pd

# %%
import numpy as  np

# %%
dfcc = pd.read_csv(r"C:\Users\ajjup\OneDrive\Desktop\DATASETS\Classification\Ensemble Learning\Random Forest\creditcard.csv")

# %%
dfcc
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dfcc.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
dfcc.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
dfcc['Class']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
dfcc["Class"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
dfcc["Class"].value_counts().plot(kind =  "bar")
# Out:
# <AxesSubplot:>

# %%
dfcc["Class"].value_counts().plot(kind =  "pie")
# Out:
# <AxesSubplot:ylabel='Class'>

# %%
dfcc["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
dfcc
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
dfcc["Class"]  == 0
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 284802    True
# 284803    True
# 284804    True
# 284805    True
# 284806    True
# Name: Class, Length: 284807, dtype: bool

# %%
dfvalid  = dfcc[dfcc["Class"]  == 0 ]

# %%
dfcc.shape
# Out:
# (284807, 31)

# %%
dfinvalid = dfcc[dfcc["Class"] == 1]

# %%
dfinvalid
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
dfvalid.shape
# Out:
# (284315, 31)

# %%
dfinvalid.shape
# Out:
# (492, 31)

# %%
dfvalid = dfvalid.sample(492)

# %%
dfinvalid.shape
# Out:
# (492, 31)

# %%
dfvalid.shape
# Out:
# (492, 31)

# %%
dfcredit = pd.concat([dfvalid, dfinvalid])

# %%
dfcredit
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 111595   72288.0 -1.681296  0.182259  2.113719  0.023329 -0.390470  2.072123
# 56961    47694.0  1.138149 -0.698637  0.332976  0.272394 -0.629432  0.463714
# 206787  136371.0  2.244952 -0.626194 -1.593599 -0.958367 -0.138658 -0.977733
# 10573    17526.0 -6.670606  5.163815 -9.484282  4.849274  2.782462  1.029472
# 209434  137557.0 -0.849299  0.033344  2.288401 -1.403874 -0.409659  0.946624
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
dfcredit["Class"].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
dfcredit["Class"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
dfcredit["Class"].value_counts().plot(kind = "pie")
# Out:
# <AxesSubplot:ylabel='Class'>

# %%
dfcredit
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 111595   72288.0 -1.681296  0.182259  2.113719  0.023329 -0.390470  2.072123
# 56961    47694.0  1.138149 -0.698637  0.332976  0.272394 -0.629432  0.463714
# 206787  136371.0  2.244952 -0.626194 -1.593599 -0.958367 -0.138658 -0.977733
# 10573    17526.0 -6.670606  5.163815 -9.484282  4.849274  2.782462  1.029472
# 209434  137557.0 -0.849299  0.033344  2.288401 -1.403874 -0.409659  0.946624
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
dfcredit = dfcredit.reset_index()

# %%
dfcredit
# Out:
#       index      Time        V1        V2        V3        V4        V5  \
# 0    111595   72288.0 -1.681296  0.182259  2.113719  0.023329 -0.390470
# 1     56961   47694.0  1.138149 -0.698637  0.332976  0.272394 -0.629432
# 2    206787  136371.0  2.244952 -0.626194 -1.593599 -0.958367 -0.138658
# 3     10573   17526.0 -6.670606  5.163815 -9.484282  4.849274  2.782462
# 4    209434  137557.0 -0.849299  0.033344  2.288401 -1.403874 -0.409659
# ..      ...       ...       ...       ...       ...       ...       ...
# 979  279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487
# 980  280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581
# 981  280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541
# 982  281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618
# 983  281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147
#
#            V6        V7        V8  ...       V21       V22       V23  \
# ...

# %%
dfcredit.drop('index', axis = 1,inplace=True)

# %%
dfcredit
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0     72288.0 -1.681296  0.182259  2.113719  0.023329 -0.390470  2.072123
# 1     47694.0  1.138149 -0.698637  0.332976  0.272394 -0.629432  0.463714
# 2    136371.0  2.244952 -0.626194 -1.593599 -0.958367 -0.138658 -0.977733
# 3     17526.0 -6.670606  5.163815 -9.484282  4.849274  2.782462  1.029472
# 4    137557.0 -0.849299  0.033344  2.288401 -1.403874 -0.409659  0.946624
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 980  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 981  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 982  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 983  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
X = dfcredit.drop('Class', axis = 1)

# %%
X
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 0     72288.0 -1.681296  0.182259  2.113719  0.023329 -0.390470  2.072123
# 1     47694.0  1.138149 -0.698637  0.332976  0.272394 -0.629432  0.463714
# 2    136371.0  2.244952 -0.626194 -1.593599 -0.958367 -0.138658 -0.977733
# 3     17526.0 -6.670606  5.163815 -9.484282  4.849274  2.782462  1.029472
# 4    137557.0 -0.849299  0.033344  2.288401 -1.403874 -0.409659  0.946624
# ..        ...       ...       ...       ...       ...       ...       ...
# 979  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 980  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 981  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 982  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 983  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#            V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
y = dfcredit["Class"]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 979    1
# 980    1
# 981    1
# 982    1
# 983    1
# Name: Class, Length: 984, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest, ytrain, ytest = train_test_split(X,y,test_size=0.20)

# %%
Xtrain.shape, Xtest.shape,  X.shape
# Out:
# ((787, 30), (197, 30), (984, 30))

# %%
ytrain.shape, ytest.shape,  y.shape
# Out:
# ((787,), (197,), (984,))

# %%
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(Xtrain, ytrain)
# Out:
# RandomForestClassifier()

# %%
rfc.score(Xtest, ytest)
# Out:
# 0.9187817258883249

# %% [markdown]
# ### Bagging Classifier

# %%
bag =  BaggingClassifier()

# %%
bag.fit(Xtrain, ytrain)
# Out:
# BaggingClassifier()

# %%
bag.score(Xtest,ytest)
# Out:
# 0.9035532994923858

# %% [markdown]
# ###  SVM with Bagging Classifier

# %%
from sklearn.svm import SVC

# %%
bagsvm = BaggingClassifier(base_estimator= SVC(), n_estimators=50)

# %%
bagsvm.fit(Xtrain, ytrain)
# Out:
# BaggingClassifier(base_estimator=SVC(), n_estimators=50)

# %%
bagsvm.score(Xtest,ytest)
# Out:
# 0.5685279187817259
